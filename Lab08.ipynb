# %% [markdown]
# <a href="https://colab.research.google.com/github/Raziya117/AIML_Lab_2024/blob/main/Lab08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline

# %%
from sklearn.datasets import fetch_openml
car_data=fetch_openml(name='car',version=2,parser='auto')

# %%
car_data.feature_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety']

# %%
car_data = car_data.frame
car_data.head()
# Out:
#   buying  maint doors persons lug_boot safety binaryClass
# 0  vhigh  vhigh     2       2    small    low           P
# 1  vhigh  vhigh     2       2    small    med           P
# 2  vhigh  vhigh     2       2    small   high           P
# 3  vhigh  vhigh     2       2      med    low           P
# 4  vhigh  vhigh     2       2      med    med           P

# %%
type(car_data)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
train_data,test_data = train_test_split(car_data,test_size=0.3,random_state=20)

# %%
print('The size of training data is: {} \n The size of testing data is: {}'.format(len(train_data),len(test_data)))
# Out:
# The size of training data is: 1209
#  The size of testing data is: 519

# %%
train_data.describe()
# Out:
#        buying maint  doors persons lug_boot safety binaryClass
# count    1209  1209   1209    1209     1209   1209        1209
# unique      4     4      4       3        3      3           2
# top       med  high  5more    more      big    med           P
# freq      327   311    319     418      411    406         849

# %%
train_data.isnull().sum()
# Out:
# buying         0
# maint          0
# doors          0
# persons        0
# lug_boot       0
# safety         0
# binaryClass    0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='maint',hue='binaryClass')
# Out:
# <Axes: xlabel='maint', ylabel='count'>
